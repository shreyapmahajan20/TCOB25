# %%
import pandas as pd
import numpy as np
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.mean(numeric_only=True))
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
print(df.mode(numeric_only=True).iloc[0])
# Out:
# sepal_length    5.0
# sepal_width     3.0
# petal_length    1.5
# petal_width     0.2
# Name: 0, dtype: float64

# %%
print("\nMedian:\n", df.median(numeric_only=True))
# Out:
# Median:
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
arr1= np.array(df['sepal_length'])
arr2= np.array(df['sepal_width'])
arr3= np.array(df['petal_length'])
arr4= np.array(df['petal_width'])

# %%
print("Sepal length:",arr1)
print("Sepal width :",arr2)
print("petal length :",arr3)
print("petal width :",arr4)
# Out:
# Sepal length: [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]
# Sepal width : [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#  3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  3.5 3.1 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
# ...

# %%
print ("Maximum sepal length : ",max(arr1))
print ("Maximum sepal width : ",max(arr2))
print ("Maximum petal length : ",max(arr3))
print ("Maximum petal width : ",max(arr4))
# Out:
# Maximum sepal length :  7.9
# Maximum sepal width :  4.4
# Maximum petal length :  6.9
# Maximum petal width :  2.5

# %%
print ("Minimum sepal length : ",min(arr1))
print ("Minimum sepal width : ",min(arr2))
print ("Minimum petal length : ",min(arr3))
print ("Minimum petal width : ",min(arr4))
# Out:
# Minimum sepal length :  4.3
# Minimum sepal width :  2.0
# Minimum petal length :  1.0
# Minimum petal width :  0.1

# %%
sepl_len=np.std(arr1)
print(sepl_len)
# Out:
# 0.8253012917851409

# %%
sepal_w=np.std(arr2)
print(sepal_w)
# Out:
# 0.4321465800705435

# %%
p_len=np.std(arr3)
print(p_len)
# Out:
# 1.7585291834055212

# %%
p_w=np.std(arr4)
print(p_w)
# Out:
# 0.7606126185881716

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#plots

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('iris')
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['sepal_length'], kde=True, bins=20, color="blue")
plt.title("Distribution of Sepal Length")
plt.show()

# %%
sns.distplot(x = dataset['sepal_length'], bins = 10, kde=False)
# Out:
# <ipython-input-11-c0e93a40180b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset['sepal_length'], bins = 10, kde=False)
# <Axes: >

# %%
#jointplot
sns.jointplot(x = dataset['petal_length'], y = dataset['petal_width'], kind =
'scatter')
sns.jointplot(x = dataset['petal_length'], y = dataset['petal_width'], kind = 'hex')

# %%
sns.rugplot(dataset['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sns.barplot(x=df['species'], palette="viridis",color="blue")
# Out:
# <ipython-input-16-0e077da37013>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['species'], palette="viridis",color="blue")
# <Axes: xlabel='species'>
